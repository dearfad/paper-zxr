# %%
from pathlib import Path
# 指定原始图片目录
raw_image_dir = Path('.')/'data'/ 'raw'
# 文件名校验
for filename in raw_image_dir.iterdir():
    print(filename.name)
# Out:
# MCF7_0_24h_CT_10x.tif
# MCF7_0_24h_CT_20x.tif
# MCF7_0_24h_CT_40x.tif
# MCF7_0_24h_LL_10x.tif
# MCF7_0_24h_LL_20x.tif
# MCF7_0_24h_LL_40x.tif
# MCF7_0_24h_LR_10x.tif
# MCF7_0_24h_LR_20x.tif
# MCF7_0_24h_LR_40x.tif
# MCF7_0_24h_UL_10x.tif
# MCF7_0_24h_UL_20x.tif
# MCF7_0_24h_UL_40x.tif
# MCF7_0_24h_UR_10x.tif
# MCF7_0_24h_UR_20x.tif
